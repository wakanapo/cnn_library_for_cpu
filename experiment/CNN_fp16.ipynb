# %%
import numpy as np
import pickle
import tensorflow as tf

# %%
import os
home=os.environ['HOME']

# %%
with open(home+"/utokyo-kudohlab/cnn_cpp/data/grad_fp16.pkl", 'rb') as fr:
    params_fp = pickle.load(fr)

# %%
dw1_fp = params_fp['W1']
dw2_fp = params_fp['W2']
dw3_fp = params_fp['W3']
db1_fp = params_fp['b1']
db2_fp = params_fp['b2']
db3_fp = params_fp['b3']

# %%
with open(home+"/utokyo-kudohlab/cnn_cpp/data/grad.pkl", 'rb') as fr:
    params = pickle.load(fr)

# %%
dw1 = params['W1']
dw2 = params['W2']
dw3 = params['W3']
db1 = params['b1']
db2 = params['b2']
db3 = params['b3']

# %%
import matplotlib.pyplot as plt

_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(dw1_fp.flatten(), bins=100, range=(-0.0075, 0.01))
axR.hist(dw1.flatten(), bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(dw2_fp.flatten(), bins=100,range=(-0.002, 0.002))
axR.hist(dw2.flatten(), bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(dw3_fp.flatten(), bins=100,range=(-0.3, 0.005))
axR.hist(dw3.flatten(), bins=100, color='green')
plt.show()

# %%
with open(home+"/utokyo-kudohlab/cnn_cpp/data/params_fp16.pkl", 'rb') as fr:
    paramsfp16 = pickle.load(fr)

# %%
aw1 = paramsfp16['W1']
aw2 = paramsfp16['W2']
aw3 = paramsfp16['W3']
ab1 = paramsfp16['b1']
ab2 = paramsfp16['b2']
ab3 = paramsfp16['b3']

# %%
with open(home+"/utokyo-kudohlab/cnn_cpp/data/before_fp16.pkl", 'rb') as fr:
    beforefp16 = pickle.load(fr)

# %%
bw1 = beforefp16['W1']
bw2 = beforefp16['W2']
bw3 = beforefp16['W3']
bb1 = beforefp16['b1']
bb2 = beforefp16['b2']
bb3 = beforefp16['b3']

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(bw1.flatten(), bins=100)
axR.hist(aw1.flatten(), bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(bw2.flatten(), bins=100)
axR.hist(aw2.flatten(), bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(bw3.flatten(), bins=100)
axR.hist(aw3.flatten(), bins=100, color='green')
plt.show()

# %%
plt.hist((aw1-bw1).flatten(), bins=100)
plt.show()

# %%
plt.hist((aw2-bw2).flatten(), bins=100)
plt.show()

# %%
plt.hist((aw3-bw3).flatten(), bins=100)
plt.show()
