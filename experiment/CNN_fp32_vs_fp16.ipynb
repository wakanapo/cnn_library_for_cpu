# %%
import numpy as np
import pickle
import tensorflow as tf
import matplotlib.pyplot as plt
import os
home=os.environ['HOME']

# %%
with open(home+"/utokyo-kudohlab/cnn_cpp/data/params_fp16.pkl", 'rb') as fr:
    paramsfp16 = pickle.load(fr)

# %%
w1fp16 = paramsfp16['W1']
w2fp16 = paramsfp16['W2']
w3fp16 = paramsfp16['W3']
b1fp16 = paramsfp16['b1']
b2fp16 = paramsfp16['b2']
b3fp16 = paramsfp16['b3']

# %%
with open(home+"/utokyo-kudohlab/cnn_cpp/data/params.pkl", 'rb') as fr:
    paramsfp32 = pickle.load(fr)

# %%
w1fp32 = paramsfp32['W1']
w2fp32 = paramsfp32['W2']
w3fp32 = paramsfp32['W3']
b1fp32 = paramsfp32['b1']
b2fp32 = paramsfp32['b2']
b3fp32 = paramsfp32['b3']

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(w1fp16.flatten(), range=(-0.6, 0.4), bins=100)
axR.hist(w1fp32.flatten(), bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(w2fp16.flatten(), range=(-0.4, 0.4), bins=100)
axR.hist(w2fp32.flatten(), range=(-0.4, 0.4), bins=100, color='green')
plt.show()

# %%
_, (axL, axR) = plt.subplots(ncols=2, figsize=(10,4))
axL.hist(w3fp16.flatten(), range=(-0.4, 0.4), bins=100)
axR.hist(w3fp32.flatten(), range=(-0.4, 0.4), bins=100, color='green')
plt.show()
